# %% [markdown]
# <a href="https://colab.research.google.com/github/Oliveiraa31/Oliveiraa31/blob/main/Opera%C3%A7%C3%B5es_e_Vari%C3%A1veis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  Operadores Aritméticos

# %%
# Adição
18 + 2
# Out:
# 20

# %%
# Subtração
10 - 2
# Out:
# 8

# %%
# Multiplicação
10 * 2
# Out:
# 20

# %%
# Divisão
10 / 2
# Out:
# 5.0

# %%
# Divisão inteira
10 // 2
# Out:
# 5

# %%
# Resto da divisão
10 % 2
# Out:
# 0

# %%
# Potenciação
10 ** 2
# Out:
# 100

# %% [markdown]
# Operadores relacionais

# %%
# Menor
10 < 2
# Out:
# False

# %%
# Menor ou igual
10 <= 2
# Out:
# False

# %%
# Maior
10 > 2
# Out:
# True

# %%
# Maior ou igual
10 >= 2
# Out:
# True

# %%
# Igual
7 == 7
# Out:
# True

# %%
# Diferente
7 != 7
# Out:
# False

# %% [markdown]
# Operadores Lógicos
#
# .And
# .Or
# .Not
#
# Tabela Verdade
#
#
# And

# %%
print(10 > 2 and 4 < 6)   # V and V - V
print(10 > 2 and 4 > 6)   # V and F - F
print(10 < 2 and 4 < 6)   # F and V - F
print(10 < 2 and 4 > 6)   # F and F - F
# Out:
# True
# False
# False
# False

# %% [markdown]
# Or

# %%
print(10 > 2 or 4 < 6)   # V or V - V
print(10 > 2 or 4 > 6)   # V or F - V
print(10 < 2 or 4 < 6)   # F or V - V
print(10 < 2 or 4 > 6)   # F or F - F
# Out:
# True
# True
# True
# False

# %% [markdown]
# Not

# %%
not 10 > 2  # V - F
# Out:
# False

# %%
not 10 < 2 # F - V
# Out:
# True

# %% [markdown]
# Variáveis
#
# Variáveis estão alocadas em espaços de memória
#
#
# Ao criar uma variável
#
# . Python aloca um espaço na memória
#
# . Referencia utilizando o nome atribuído à varável pelo programador no moneto de sua criação
#
# . Exemplo
#
# """ Nome da variável é "x" que armazena o valor 10 em um espaço na memória """
#
# >>> x = 10
#
# >>> print (x)
#
# 10
#
# Regras  de variáveis
#
# Nome da variável
#
# . Começar com letra (a-z, A-Z) ou sublinhado (_)
#
# . São Case Sensitive (Diferença entre letras maiúscula e minúscula)
#
# . Exemplo
#
# >>> A !=a
#
# Regras de variáveis
#
# Boas práticas para nome da variável
#
# . Usar nomes que definam o que ela faz no programa
# . Não usar nomes longos
#
#
# Exemplo de soma de 2 números
#
# Recomendado
#
#
# soma = 2 + 5
#
#
# Soma_total = 2 + 5
#
# somaTotal = 2 + 5
#
#
#
# Não recomendados
#
# soma_dois_números_inteiros = 2 + 5
#
# somaDeDoisNumerosInteiros = 2 + 5
#
#
# Tipos de varáveis
#
# Python é uma linguagem de alto nível
#
# . Não é necessário especificar o tipo de dados quando declarar a varável
#
# . Python defini o tipo de dados na declaração
#
#
# Tipo
#
# Int (Inteiro)
#
# Float ( Real)
#
# String (Texto)
#
# Exemplo
#
# num = 10
#
# num = 10.5
#
# nome = "Caroline"
