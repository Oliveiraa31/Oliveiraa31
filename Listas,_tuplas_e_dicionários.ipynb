# %% [markdown]
# <a href="https://colab.research.google.com/github/Oliveiraa31/Oliveiraa31/blob/main/Listas%2C_tuplas_e_dicion%C3%A1rios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Listas, tuplas e dicionários

# %%
# Lista
[1,2,3,4,5]
# Out:
# [1, 2, 3, 4, 5]

# %%
# Tupla
(1,2,3,4,5)
# Out:
# (1, 2, 3, 4, 5)

# %%
# Dicionário
{"num1": 1,"num2": 2}
# Out:
# {'num1': 1, 'num2': 2}

# %% [markdown]
# Lista

# %%
lista =[5, "Caroline", 8.9]

# %%
type(lista)
# Out:
# list

# %%
lista.append("Caroline") # Adicionar um elemento na lista

# %%
print(lista)
print(lista[1])
# Out:
# [5, 'Caroline', 8.9]
# Caroline
