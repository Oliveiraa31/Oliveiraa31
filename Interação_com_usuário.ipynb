# %% [markdown]
# <a href="https://colab.research.google.com/github/Oliveiraa31/Oliveiraa31/blob/main/Intera%C3%A7%C3%A3o_com_usu%C3%A1rio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Visualização de Variáveis e textos

# %%
print("Conhecendo o comando Print")

x = 8
print(x)
# Out:
# Conhecendo o comando Print
# 8

# %%
y = 10
soma = x + y
print(soma)
# Out:
# 18

# %%
nome = "Caroline Oliveira"
print(nome)
# Out:
# Caroline Oliveira

# %% [markdown]
# Concatenação

# %%
x = 5
print("O valor de x é", x)
# Out:
# O valor de x é 5

# %%
print("O valor de x é", x, "e o dobro é", x * 2)
# Out:
# O valor de x é 5 e o dobro é 10

# %%
print("Eu", nome, "tirei", x, "na prova de Python")
# Out:
# Eu Caroline Oliveira tirei 5 na prova de Python

# %%
y = 10; z = 20 + x - y

print("Declarar várias variáveis na mesma linha:", y, z)
# Out:
# Declarar várias variáveis na mesma linha 10 15

# %% [markdown]
# Type

# %%
x = 10
type(x)
print("x", type(x))

nome = "Caroline"
print("nome", type(nome))

num = "100"
num_convert = int(num)
print("num", type(num))
print("num_convert", type(num_convert))

num_float = float(num)
print("num_float", type(num_float))
# Out:
# x <class 'int'>
# nome <class 'str'>
# num <class 'str'>
# num_convert <class 'int'>
# num_float <class 'float'>
